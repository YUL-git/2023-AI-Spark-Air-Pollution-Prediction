# %%
#Library Imports
import numpy as np
import pandas as pd
import math
import os
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error

#######딥러닝 라이브러리##########
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Reshape, GRU, RNN

tf.keras.backend.set_floatx('float64')

# %%
meta_awsmap = pd.read_csv('./META/awsmap.csv')
meta_pmmap = pd.read_csv('./META/pmmap.csv')

# %% [markdown]
# ## 사용할 aws 데이터 선별하기

# %%
# 가장 가까운 동네 찾기
meta_aws = meta_awsmap.loc[:,['Location','Latitude','Longitude']]
meta_pm = meta_pmmap.loc[:,['Location','Latitude','Longitude']]

# %%
# pm 관측별 AWS 가장 가까운 지역 선별
from math import radians, sin, cos, sqrt, atan2

def haversine(lat1, lon1, lat2, lon2):
    # 지구의 반지름 (km)
    R = 6371.0

    # 라디안으로 변환
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    # 경도, 위도 차이 계산
    dlon = lon2 - lon1
    dlat = lat2 - lat1

    # Haversine 공식 적용
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c

    return distance

best_aws = []
idx = ''

for index, row in meta_pm.iterrows():
    min_dist = 1e15
    location = row['Location']
    latitude = row['Latitude']
    longitude = row['Longitude']
    
    for index, row2 in meta_aws.iterrows():
        location2 = row2['Location']
        latitude2 = row2['Latitude']
        longitude2 = row2['Longitude']
        dist = haversine(latitude, longitude, latitude2, longitude2)
        if min_dist > dist:
            min_dist = dist
            idx, loca = index, location2
        else:
            continue
            
    best_aws.append([location, idx, loca])

# %%
best_aws
# Out:
# [['아름동', 3, '세종고운'],
#  ['신흥동', 5, '세종연서'],
#  ['노은동', 24, '계룡'],
#  ['문창동', 0, '오월드'],
#  ['읍내동', 2, '장동'],
#  ['정림동', 0, '오월드'],
#  ['공주', 12, '공주'],
#  ['논산', 14, '논산'],
#  ['대천2동', 26, '대천항'],
#  ['독곶리', 9, '대산'],
#  ['동문동', 18, '태안'],
#  ['모종동', 22, '아산'],
#  ['신방동', 16, '성거'],
#  ['예산군', 19, '예산'],
#  ['이원면', 18, '태안'],
#  ['홍성읍', 10, '홍북'],
#  ['성성동', 16, '성거']]

# %% [markdown]
# ## 데이터 불러오기

# %%
# Train
pm_공주 = pd.read_csv('./TRAIN/공주.csv')
pm_신방동 = pd.read_csv('./TRAIN/신방동.csv')
pm_정림동 = pd.read_csv('./TRAIN/정림동.csv')
pm_이원면 = pd.read_csv('./TRAIN/이원면.csv')
pm_읍내동 = pd.read_csv('./TRAIN/읍내동.csv')
pm_예산군 = pd.read_csv('./TRAIN/예산군.csv')
pm_아름동 = pd.read_csv('./TRAIN/아름동.csv')
pm_신흥동 = pd.read_csv('./TRAIN/신흥동.csv')
pm_성성동 = pd.read_csv('./TRAIN/성성동.csv')
pm_노은동 = pd.read_csv('./TRAIN/노은동.csv')
pm_문창동 = pd.read_csv('./TRAIN/문창동.csv')
pm_모종동 = pd.read_csv('./TRAIN/모종동.csv') 
pm_동문동 = pd.read_csv('./TRAIN/동문동.csv')
pm_독곶리 = pd.read_csv('./TRAIN/독곶리.csv')
pm_대천2동 = pd.read_csv('./TRAIN/대천2동.csv')
pm_논산 = pd.read_csv('./TRAIN/논산.csv')
pm_홍성읍 = pd.read_csv('./TRAIN/홍성읍.csv')

# %%
aws_공주 = pd.read_csv('./TRAIN_AWS/공주.csv')
aws_신방동 = pd.read_csv('./TRAIN_AWS/성거.csv')
aws_정림동 = pd.read_csv('./TRAIN_AWS/오월드.csv')
aws_이원면 = pd.read_csv('./TRAIN_AWS/태안.csv')
aws_읍내동 = pd.read_csv('./TRAIN_AWS/장동.csv')
aws_예산군 = pd.read_csv('./TRAIN_AWS/예산.csv')
aws_아름동 = pd.read_csv('./TRAIN_AWS/세종고운.csv')
aws_신흥동 = pd.read_csv('./TRAIN_AWS/세종연서.csv')
aws_성성동 = pd.read_csv('./TRAIN_AWS/성거.csv')
aws_노은동 = pd.read_csv('./TRAIN_AWS/계룡.csv')
aws_문창동 = pd.read_csv('./TRAIN_AWS/오월드.csv')
aws_모종동 = pd.read_csv('./TRAIN_AWS/아산.csv') 
aws_동문동 = pd.read_csv('./TRAIN_AWS/태안.csv')
aws_독곶리 = pd.read_csv('./TRAIN_AWS/대산.csv')
aws_대천2동 = pd.read_csv('./TRAIN_AWS/대천항.csv')
aws_논산 = pd.read_csv('./TRAIN_AWS/논산.csv')
aws_홍성읍 = pd.read_csv('./TRAIN_AWS/홍북.csv')

# %%
# Test
test_pm_공주 = pd.read_csv('./TEST_INPUT/공주.csv')
test_pm_신방동 = pd.read_csv('./TEST_INPUT/신방동.csv')
test_pm_정림동 = pd.read_csv('./TEST_INPUT/정림동.csv')
test_pm_이원면 = pd.read_csv('./TEST_INPUT/이원면.csv')
test_pm_읍내동 = pd.read_csv('./TEST_INPUT/읍내동.csv')
test_pm_예산군 = pd.read_csv('./TEST_INPUT/예산군.csv')
test_pm_아름동 = pd.read_csv('./TEST_INPUT/아름동.csv')
test_pm_신흥동 = pd.read_csv('./TEST_INPUT/신흥동.csv')
test_pm_성성동 = pd.read_csv('./TEST_INPUT/성성동.csv')
test_pm_노은동 = pd.read_csv('./TEST_INPUT/노은동.csv')
test_pm_문창동 = pd.read_csv('./TEST_INPUT/문창동.csv')
test_pm_모종동 = pd.read_csv('./TEST_INPUT/모종동.csv') 
test_pm_동문동 = pd.read_csv('./TEST_INPUT/동문동.csv')
test_pm_독곶리 = pd.read_csv('./TEST_INPUT/독곶리.csv')
test_pm_대천2동 = pd.read_csv('./TEST_INPUT/대천2동.csv')
test_pm_논산 = pd.read_csv('./TEST_INPUT/논산.csv')
test_pm_홍성읍 = pd.read_csv('./TEST_INPUT/홍성읍.csv')

# %%
test_aws_공주 = pd.read_csv('./TEST_AWS/공주.csv')
test_aws_신방동 = pd.read_csv('./TEST_AWS/성거.csv')
test_aws_정림동 = pd.read_csv('./TEST_AWS/오월드.csv')
test_aws_이원면 = pd.read_csv('./TEST_AWS/태안.csv')
test_aws_읍내동 = pd.read_csv('./TEST_AWS/장동.csv')
test_aws_예산군 = pd.read_csv('./TEST_AWS/예산.csv')
test_aws_아름동 = pd.read_csv('./TEST_AWS/세종고운.csv')
test_aws_신흥동 = pd.read_csv('./TEST_AWS/세종연서.csv')
test_aws_성성동 = pd.read_csv('./TEST_AWS/성거.csv')
test_aws_노은동 = pd.read_csv('./TEST_AWS/계룡.csv')
test_aws_문창동 = pd.read_csv('./TEST_AWS/오월드.csv')
test_aws_모종동 = pd.read_csv('./TEST_AWS/아산.csv') 
test_aws_동문동 = pd.read_csv('./TEST_AWS/태안.csv')
test_aws_독곶리 = pd.read_csv('./TEST_AWS/대산.csv')
test_aws_대천2동 = pd.read_csv('./TEST_AWS/대천항.csv')
test_aws_논산 = pd.read_csv('./TEST_AWS/논산.csv')
test_aws_홍성읍 = pd.read_csv('./TEST_AWS/홍북.csv')

# %%
submit = pd.read_csv('./answer_sample.csv')

# %%
# Train
cities = ['공주', '노은동', '논산', '대천2동', '독곶리',
          '동문동', '모종동', '문창동', '성성동', '신방동',
          '신흥동', '아름동', '예산군', '읍내동', '이원면',
          '정림동', '홍성읍']

for city in cities:
    globals()["pm_" + city] = globals()["pm_" + city].drop(['연도', '일시', '측정소'], axis=1)
    globals()["aws_" + city] = globals()["aws_" + city].drop(['연도','일시','지점'], axis=1)
    globals()["new_" + city] = pd.concat([globals()["aws_" + city], globals()["pm_" + city]], axis=1)
    globals()["new_" + city] = globals()["new_" + city].interpolate(method='polynomial', order=5)

    if city == '대천2동':
        globals()["new_" + city].iloc[0,-1] = globals()["new_" + city].iloc[1,-1]
    
    if city == '모종동':
        globals()["new_" + city] = globals()["new_" + city].interpolate(method='bfill')
        
for city in cities:
    globals()["test_pm_" + city] = globals()["test_pm_" + city].drop(['연도', '일시', '측정소'], axis=1)
    globals()["test_aws_" + city] = globals()["test_aws_" + city].drop(['연도','일시','지점'], axis=1).interpolate(method='polynomial', order=5)
    # globals()["test_aws_" + city] = globals()["test_aws_" + city].drop(['연도','일시','지점'], axis=1).interpolate(method='linear')
    globals()["test_new_" + city] = pd.concat([globals()["test_aws_" + city], globals()["test_pm_" + city]], axis=1)
    # globals()["test_new_" + city] = globals()["test_new_" + city].iloc[:,:-1].interpolate(method='linear')

# %%
n = 0
for city in cities:
    if submit[submit['측정소'] == city].isna().sum().sum() != globals()["test_new_" + city].isna().sum().sum():
        n += 1
print(n)
# Out:
# 0

# %% [markdown]
# ## Data Loader

# %%
def window_dataset(X, y, X_size, y_size, X_shift, y_shift, X_stride, y_stride, batch_size):
    ds_x = tf.data.Dataset.from_tensor_slices(X)
    ds_x = ds_x.window(size=X_size, stride=X_stride, shift=X_shift, drop_remainder=True)
    ds_x = ds_x.flat_map(lambda x: x.batch(X_size))
    
    ds_y = tf.data.Dataset.from_tensor_slices(y)
    ds_y = ds_y.window(size=y_size, stride=y_stride, shift=y_shift, drop_remainder=True)
    ds_y = ds_y.flat_map(lambda y: y.batch(y_size))
    
    ds = tf.data.Dataset.zip((ds_x, ds_y))
    return ds.batch(batch_size).prefetch(1)

def window_test_dataset(X, X_size, X_shift, X_stride, batch_size):
    ds_x = tf.data.Dataset.from_tensor_slices(X)
    ds_x = ds_x.window(size=X_size, stride=X_stride, shift=X_shift, drop_remainder=True)
    ds_x = ds_x.flat_map(lambda x: x.batch(X_size))
    
    return ds_x.batch(batch_size).prefetch(1)

# %% [markdown]
# ## LSTM train & eval

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

n_features = 5 
n_steps_in = 48
n_step_out = 72
lstm_units=16
dropout=0.2                                       

EPOCH=40
BATCH_SIZE=48  #(배치사이즈를 맞춰줌)

# X에 대한 윈도우 함수 설정값
X_size = 48
X_shift = 48
X_stride = 1

X_test_size = 48
X_test_shift = 121 # shift를 맞춰주기 위해서 48 + 72 + 1( 해당 인덱스를 포함하기 때문 )
X_test_stride = 1

# y에 대한 윈도우 함수 설정값
y_size = 72
y_shift = 72
y_stride = 1

batch_size = 48

# Train
cities = ['공주', '노은동', '논산', '대천2동', '독곶리',
          '동문동', '모종동', '문창동', '성성동', '신방동',
          '신흥동', '아름동', '예산군', '읍내동', '이원면',
          '정림동', '홍성읍']
answer = []
n = 1
for city in cities:
    print(n,'번째',city,'지역의 미세먼지 예측을 시작하겠습니다.')
    n += 1
    globals()["X_"+ city], globals()["y_"+city] = globals()["new_" + city].iloc[:,:-1].values, globals()["new_" + city].iloc[:,[-1]].values
    # globals()["X_test"+ city] = globals()["test_new_" + city][~globals()["test_new_" + city]['PM2.5'].isna()].interpolate(method='linear')
    globals()["X_test"+ city] = globals()["test_new_"+ city].iloc[:,:-1].values

    X_train, X_val, y_train, y_val = train_test_split(globals()["X_"+ city], globals()["y_"+city], test_size=0.2, random_state=42)

    train_dataset = window_dataset(X_train, y_train, X_size, y_size, X_shift, y_shift, X_stride, y_stride, batch_size)
    val_dataset = window_dataset(X_val, y_val, X_size, y_size, X_shift, y_shift, X_stride, y_stride, batch_size)

    test_dataset = window_test_dataset(globals()["X_test"+ city], X_test_size, X_test_shift, X_test_stride, batch_size)

    ######## LSTM #######
    model=Sequential([
    LSTM(lstm_units, activation='relu', input_shape=(n_steps_in, n_features)),
    # LSTM(lstm_units, activation='relu', return_sequences=True, recurrent_dropout=dropout, input_shape=(n_steps_in, n_features)),
    # LSTM(lstm_units, activation='relu'),
    Dense(n_step_out, activation='linear'),
    ])

    #######Compile 구성하기################
    model.compile(optimizer='rmsprop', loss='mae', metrics=['mae'])

    # 에포크가 끝날 때마다 점(.)을 출력해 훈련 진행 과정을 표시합니다
    class PrintDot(tf.keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs):
            if epoch % 10 == 0: print('')
            print('.', end='')

    #가장 좋은 성능을 낸 val_loss가 적은 model만 남겨 놓았습니다.
    save_best_only=tf.keras.callbacks.ModelCheckpoint(filepath="lstm_model.h5", monitor='val_loss', save_best_only=True)


    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

    #검증 손실이 10epoch 동안 좋아지지 않으면 학습률을 0.1 배로 재구성하는 명령어입니다.
    reduceLR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)

    history = model.fit(train_dataset, epochs=EPOCH, batch_size=BATCH_SIZE, validation_data = val_dataset, verbose=1,
                    callbacks=[PrintDot(), early_stop, save_best_only , reduceLR])

    predictions = model.predict(test_dataset)
    predictions = predictions.reshape(-1,1)
    
    answer.append(predictions)
# Out:
# 1 번째 공주 지역의 미세먼지 예측을 시작하겠습니다.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/40
#       9/Unknown - 3s 88ms/step - loss: 0.0937 - mae: 0.0937
# 9/9 [==============================] - 4s 208ms/step - loss: 0.0937 - mae: 0.0937 - val_loss: 0.0788 - val_mae: 0.0788 - lr: 0.0010
# Epoch 2/40
# 9/9 [==============================] - 1s 112ms/step - loss: 0.0732 - mae: 0.0732 - val_loss: 0.0656 - val_mae: 0.0656 - lr: 0.0010
# Epoch 3/40
# 9/9 [==============================] - 1s 103ms/step - loss: 0.0620 - mae: 0.0620 - val_loss: 0.0579 - val_mae: 0.0579 - lr: 0.0010
# Epoch 4/40
# 9/9 [==============================] - 1s 119ms/step - loss: 0.0557 - mae: 0.0557 - val_loss: 0.0538 - val_mae: 0.0538 - lr: 0.0010
# Epoch 5/40
# 9/9 [==============================] - 1s 112ms/step - loss: 0.0526 - mae: 0.0526 - val_loss: 0.0519 - val_mae: 0.0519 - lr: 0.0010
# Epoch 6/40
# 1/9 [==>...........................] - ETA: 1s - loss: 0.0515 - mae: 0.0515
# KeyboardInterrupt

# %% [markdown]
# ## LSTM with Scale & Cross validation

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

n_features = 5 
n_steps_in = 48
n_step_out = 72
lstm_units=16
dropout=0.2                                       

EPOCH= 50
BATCH_SIZE=48  #(배치사이즈를 맞춰줌)

# X에 대한 윈도우 함수 설정값
X_size = 48
X_shift = 48
X_stride = 1

# X_val_size = 48
# X_val_shift = 97 # shift를 맞춰주기 위해서 48 + 48 + 1( 해당 인덱스를 포함하기 때문 )
# X_val_stride = 1

X_test_size = 48
X_test_shift = 121 # shift를 맞춰주기 위해서 48 + 72 + 1( 해당 인덱스를 포함하기 때문 )
X_test_stride = 1

# y에 대한 윈도우 함수 설정값
y_size = 72
y_shift = 72
y_stride = 1

batch_size = 48

# Train
cities = ['공주', '노은동', '논산', '대천2동', '독곶리',
          '동문동', '모종동', '문창동', '성성동', '신방동',
          '신흥동', '아름동', '예산군', '읍내동', '이원면',
          '정림동', '홍성읍']
final_answer = []
n = 1
for city in cities:
    answer = []
    score = []
    
    print(n,'번째',city,'지역의 미세먼지 예측을 시작하겠습니다.')
    n += 1
    
    globals()["X_"+ city], globals()["y_"+city] = globals()["new_" + city].iloc[:,:-1].values, globals()["new_" + city].iloc[:,[-1]].values
    globals()["X_test"+ city] = globals()["test_new_"+ city].iloc[:,:-1].values

    scale = StandardScaler()
    globals()["X_"+ city] = scale.fit_transform(globals()["X_"+ city])
    globals()["X_test"+ city] = scale.transform(globals()["X_test"+ city])
    
    
    tscv = TimeSeriesSplit(n_splits=5)
    for train_index, val_index in tscv.split(globals()["X_"+ city]):
        X_train, X_val = globals()["X_"+ city][train_index], globals()["X_"+ city][val_index]
        y_train, y_val = globals()["y_"+city][train_index], globals()["y_"+city][val_index]

        train_dataset = window_dataset(X_train, y_train, X_size, y_size, X_shift, y_shift, X_stride, y_stride, batch_size)
        val_dataset = window_dataset(X_val, y_val, X_size, y_size, X_shift, y_shift, X_stride, y_stride, batch_size)
        test_dataset = window_test_dataset(globals()["X_test"+ city], X_test_size, X_test_shift, X_test_stride, batch_size)        
        
        # X_val_dataset = window_test_dataset(X_val, X_val_size, X_val_shift, X_val_stride, batch_size)
        # y_val_dataset = window_test_dataset(y_val, y_size, y_shift, y_stride, batch_size)

        ######## LSTM #######
        model=Sequential([
        LSTM(lstm_units, activation='relu', input_shape=(n_steps_in, n_features)),
        # LSTM(lstm_units, activation='relu', return_sequences=True, recurrent_dropout=dropout, input_shape=(n_steps_in, n_features)),
        # LSTM(lstm_units, activation='relu'),
        Dense(n_step_out, activation='linear'),
        ])

        #######Compile 구성하기################
        model.compile(optimizer='rmsprop', loss='mae', metrics=['mae'])

        # 에포크가 끝날 때마다 점(.)을 출력해 훈련 진행 과정을 표시합니다
        class PrintDot(tf.keras.callbacks.Callback):
            def on_epoch_end(self, epoch, logs):
                if epoch % 10 == 0: print('')
                print('.', end='')

        #가장 좋은 성능을 낸 val_loss가 적은 model만 남겨 놓았습니다.
        save_best_only=tf.keras.callbacks.ModelCheckpoint(filepath="lstm_model.h5", monitor='val_loss', save_best_only=True)

        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

        #검증 손실이 10epoch 동안 좋아지지 않으면 학습률을 0.1 배로 재구성하는 명령어입니다.
        reduceLR = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)

        history = model.fit(train_dataset, epochs=EPOCH, batch_size=BATCH_SIZE, validation_data = val_dataset, verbose=1,
                        callbacks=[PrintDot(), early_stop, save_best_only , reduceLR])
        
        predictions = model.predict(test_dataset)
        predictions = predictions.reshape(1,-1)
        answer.append(predictions)
        
    final_answer.append(np.mean(answer, axis = 0))
# Out:
# 1 번째 공주 지역의 미세먼지 예측을 시작하겠습니다.
# WARNING:tensorflow:Layer lstm_85 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       2/Unknown - 1s 74ms/step - loss: 0.2458 - mae: 0.2458
# 2/2 [==============================] - 2s 482ms/step - loss: 0.2458 - mae: 0.2458 - val_loss: 0.3533 - val_mae: 0.3533 - lr: 0.0010
# Epoch 2/50
# 2/2 [==============================] - 0s 202ms/step - loss: 0.2354 - mae: 0.2354 - val_loss: 0.3468 - val_mae: 0.3468 - lr: 0.0010
# Epoch 3/50
# 2/2 [==============================] - 0s 181ms/step - loss: 0.2294 - mae: 0.2294 - val_loss: 0.3420 - val_mae: 0.3420 - lr: 0.0010
# Epoch 4/50
# 2/2 [==============================] - 0s 194ms/step - loss: 0.2248 - mae: 0.2248 - val_loss: 0.3380 - val_mae: 0.3380 - lr: 0.0010
# Epoch 5/50
# 2/2 [==============================] - 0s 208ms/step - loss: 0.2210 - mae: 0.2210 - val_loss: 0.3346 - val_mae: 0.3346 - lr: 0.0010
# Epoch 6/50
# 2/2 [==============================] - 0s 195ms/step - loss: 0.2177 - mae: 0.2177 - val_loss: 0.3315 - val_mae: 0.3315 - lr: 0.0010
# Epoch 7/50
# 2/2 [==============================] - 0s 187ms/step - loss: 0.2148 - mae: 0.2148 - val_loss: 0.3289 - val_mae: 0.3289 - lr: 0.0010
# Epoch 8/50
# 2/2 [==============================] - 0s 206ms/step - loss: 0.2122 - mae: 0.2122 - val_loss: 0.3264 - val_mae: 0.3264 - lr: 0.0010
# Epoch 9/50
# 2/2 [==============================] - 0s 172ms/step - loss: 0.2098 - mae: 0.2098 - val_loss: 0.3242 - val_mae: 0.3242 - lr: 0.0010
# Epoch 10/50
# 2/2 [==============================] - 0s 191ms/step - loss: 0.2077 - mae: 0.2077 - val_loss: 0.3223 - val_mae: 0.3223 - lr: 0.0010
# Epoch 11/50
# 2/2 [==============================] - ETA: 0s - loss: 0.2057 - mae: 0.2057
# 2/2 [==============================] - 0s 189ms/step - loss: 0.2057 - mae: 0.2057 - val_loss: 0.3204 - val_mae: 0.3204 - lr: 0.0010
# Epoch 12/50
# 2/2 [==============================] - 0s 201ms/step - loss: 0.2039 - mae: 0.2039 - val_loss: 0.3186 - val_mae: 0.3186 - lr: 0.0010
# Epoch 13/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.2022 - mae: 0.2022 - val_loss: 0.3170 - val_mae: 0.3170 - lr: 0.0010
# Epoch 14/50
# 2/2 [==============================] - 0s 179ms/step - loss: 0.2006 - mae: 0.2006 - val_loss: 0.3154 - val_mae: 0.3154 - lr: 0.0010
# Epoch 15/50
# 2/2 [==============================] - 0s 169ms/step - loss: 0.1992 - mae: 0.1992 - val_loss: 0.3140 - val_mae: 0.3140 - lr: 0.0010
# Epoch 16/50
# 2/2 [==============================] - 0s 176ms/step - loss: 0.1979 - mae: 0.1979 - val_loss: 0.3126 - val_mae: 0.3126 - lr: 0.0010
# Epoch 17/50
# 2/2 [==============================] - 0s 169ms/step - loss: 0.1967 - mae: 0.1967 - val_loss: 0.3114 - val_mae: 0.3114 - lr: 0.0010
# Epoch 18/50
# 2/2 [==============================] - 0s 173ms/step - loss: 0.1955 - mae: 0.1955 - val_loss: 0.3103 - val_mae: 0.3103 - lr: 0.0010
# Epoch 19/50
# 2/2 [==============================] - 0s 180ms/step - loss: 0.1945 - mae: 0.1945 - val_loss: 0.3092 - val_mae: 0.3092 - lr: 0.0010
# Epoch 20/50
# 2/2 [==============================] - 0s 192ms/step - loss: 0.1935 - mae: 0.1935 - val_loss: 0.3083 - val_mae: 0.3083 - lr: 0.0010
# Epoch 21/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1926 - mae: 0.1926
# 2/2 [==============================] - 0s 199ms/step - loss: 0.1926 - mae: 0.1926 - val_loss: 0.3074 - val_mae: 0.3074 - lr: 0.0010
# Epoch 22/50
# 2/2 [==============================] - 0s 191ms/step - loss: 0.1917 - mae: 0.1917 - val_loss: 0.3065 - val_mae: 0.3065 - lr: 0.0010
# Epoch 23/50
# 2/2 [==============================] - 0s 201ms/step - loss: 0.1910 - mae: 0.1910 - val_loss: 0.3057 - val_mae: 0.3057 - lr: 0.0010
# Epoch 24/50
# 2/2 [==============================] - 0s 212ms/step - loss: 0.1903 - mae: 0.1903 - val_loss: 0.3051 - val_mae: 0.3051 - lr: 0.0010
# Epoch 25/50
# 2/2 [==============================] - 0s 217ms/step - loss: 0.1896 - mae: 0.1896 - val_loss: 0.3044 - val_mae: 0.3044 - lr: 0.0010
# Epoch 26/50
# 2/2 [==============================] - 0s 190ms/step - loss: 0.1890 - mae: 0.1890 - val_loss: 0.3040 - val_mae: 0.3040 - lr: 0.0010
# Epoch 27/50
# 2/2 [==============================] - 0s 214ms/step - loss: 0.1884 - mae: 0.1884 - val_loss: 0.3036 - val_mae: 0.3036 - lr: 0.0010
# Epoch 28/50
# 2/2 [==============================] - 0s 213ms/step - loss: 0.1879 - mae: 0.1879 - val_loss: 0.3032 - val_mae: 0.3032 - lr: 0.0010
# Epoch 29/50
# 2/2 [==============================] - 0s 218ms/step - loss: 0.1874 - mae: 0.1874 - val_loss: 0.3027 - val_mae: 0.3027 - lr: 0.0010
# Epoch 30/50
# 2/2 [==============================] - 0s 207ms/step - loss: 0.1869 - mae: 0.1869 - val_loss: 0.3025 - val_mae: 0.3025 - lr: 0.0010
# Epoch 31/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1865 - mae: 0.1865
# 2/2 [==============================] - 0s 178ms/step - loss: 0.1865 - mae: 0.1865 - val_loss: 0.3021 - val_mae: 0.3021 - lr: 0.0010
# Epoch 32/50
# 2/2 [==============================] - 0s 214ms/step - loss: 0.1861 - mae: 0.1861 - val_loss: 0.3019 - val_mae: 0.3019 - lr: 0.0010
# Epoch 33/50
# 2/2 [==============================] - 0s 189ms/step - loss: 0.1857 - mae: 0.1857 - val_loss: 0.3015 - val_mae: 0.3015 - lr: 0.0010
# Epoch 34/50
# 2/2 [==============================] - 0s 242ms/step - loss: 0.1854 - mae: 0.1854 - val_loss: 0.3014 - val_mae: 0.3014 - lr: 0.0010
# Epoch 35/50
# 2/2 [==============================] - 0s 186ms/step - loss: 0.1851 - mae: 0.1851 - val_loss: 0.3013 - val_mae: 0.3013 - lr: 0.0010
# Epoch 36/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1847 - mae: 0.1847 - val_loss: 0.3014 - val_mae: 0.3014 - lr: 0.0010
# Epoch 37/50
# 2/2 [==============================] - 0s 201ms/step - loss: 0.1845 - mae: 0.1845 - val_loss: 0.3010 - val_mae: 0.3010 - lr: 0.0010
# Epoch 38/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1842 - mae: 0.1842 - val_loss: 0.3011 - val_mae: 0.3011 - lr: 0.0010
# Epoch 39/50
# 2/2 [==============================] - 0s 153ms/step - loss: 0.1839 - mae: 0.1839 - val_loss: 0.3010 - val_mae: 0.3010 - lr: 0.0010
# Epoch 40/50
# 2/2 [==============================] - 0s 158ms/step - loss: 0.1837 - mae: 0.1837 - val_loss: 0.3010 - val_mae: 0.3010 - lr: 0.0010
# Epoch 41/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1835 - mae: 0.1835
# 2/2 [==============================] - 0s 171ms/step - loss: 0.1835 - mae: 0.1835 - val_loss: 0.3009 - val_mae: 0.3009 - lr: 0.0010
# Epoch 42/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1833 - mae: 0.1833 - val_loss: 0.3011 - val_mae: 0.3011 - lr: 0.0010
# Epoch 43/50
# 2/2 [==============================] - 0s 170ms/step - loss: 0.1831 - mae: 0.1831 - val_loss: 0.3010 - val_mae: 0.3010 - lr: 0.0010
# Epoch 44/50
# 2/2 [==============================] - 0s 171ms/step - loss: 0.1829 - mae: 0.1829 - val_loss: 0.3012 - val_mae: 0.3012 - lr: 0.0010
# Epoch 45/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.1827 - mae: 0.1827 - val_loss: 0.3013 - val_mae: 0.3013 - lr: 0.0010
# Epoch 46/50
# 2/2 [==============================] - 0s 174ms/step - loss: 0.1826 - mae: 0.1826 - val_loss: 0.3015 - val_mae: 0.3015 - lr: 0.0010
# Epoch 47/50
# 2/2 [==============================] - 0s 168ms/step - loss: 0.1824 - mae: 0.1824 - val_loss: 0.3018 - val_mae: 0.3018 - lr: 0.0010
# Epoch 48/50
# 2/2 [==============================] - 0s 166ms/step - loss: 0.1822 - mae: 0.1822 - val_loss: 0.3019 - val_mae: 0.3019 - lr: 1.0000e-04
# Epoch 49/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.1821 - mae: 0.1821 - val_loss: 0.3019 - val_mae: 0.3019 - lr: 1.0000e-04
# Epoch 50/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1821 - mae: 0.1821 - val_loss: 0.3020 - val_mae: 0.3020 - lr: 1.0000e-04
# 2/2 [==============================] - 0s 29ms/step
# WARNING:tensorflow:Layer lstm_86 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       4/Unknown - 2s 75ms/step - loss: 0.2856 - mae: 0.2856
# 4/4 [==============================] - 2s 199ms/step - loss: 0.2856 - mae: 0.2856 - val_loss: 0.0918 - val_mae: 0.0918 - lr: 0.0010
# Epoch 2/50
# 4/4 [==============================] - 0s 112ms/step - loss: 0.2744 - mae: 0.2744 - val_loss: 0.0853 - val_mae: 0.0853 - lr: 0.0010
# Epoch 3/50
# 4/4 [==============================] - 0s 106ms/step - loss: 0.2678 - mae: 0.2678 - val_loss: 0.0803 - val_mae: 0.0803 - lr: 0.0010
# Epoch 4/50
# 4/4 [==============================] - 0s 106ms/step - loss: 0.2628 - mae: 0.2628 - val_loss: 0.0761 - val_mae: 0.0761 - lr: 0.0010
# Epoch 5/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.2586 - mae: 0.2586 - val_loss: 0.0725 - val_mae: 0.0725 - lr: 0.0010
# Epoch 6/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2549 - mae: 0.2549 - val_loss: 0.0695 - val_mae: 0.0695 - lr: 0.0010
# Epoch 7/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.2517 - mae: 0.2517 - val_loss: 0.0668 - val_mae: 0.0668 - lr: 0.0010
# Epoch 8/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2489 - mae: 0.2489 - val_loss: 0.0645 - val_mae: 0.0645 - lr: 0.0010
# Epoch 9/50
# 4/4 [==============================] - 0s 108ms/step - loss: 0.2464 - mae: 0.2464 - val_loss: 0.0625 - val_mae: 0.0625 - lr: 0.0010
# Epoch 10/50
# 4/4 [==============================] - 0s 121ms/step - loss: 0.2442 - mae: 0.2442 - val_loss: 0.0608 - val_mae: 0.0608 - lr: 0.0010
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2423 - mae: 0.2423
# 4/4 [==============================] - 0s 102ms/step - loss: 0.2423 - mae: 0.2423 - val_loss: 0.0594 - val_mae: 0.0594 - lr: 0.0010
# Epoch 12/50
# 4/4 [==============================] - 0s 121ms/step - loss: 0.2407 - mae: 0.2407 - val_loss: 0.0582 - val_mae: 0.0582 - lr: 0.0010
# Epoch 13/50
# 4/4 [==============================] - 0s 130ms/step - loss: 0.2393 - mae: 0.2393 - val_loss: 0.0571 - val_mae: 0.0571 - lr: 0.0010
# Epoch 14/50
# 4/4 [==============================] - 0s 116ms/step - loss: 0.2381 - mae: 0.2381 - val_loss: 0.0563 - val_mae: 0.0563 - lr: 0.0010
# Epoch 15/50
# 4/4 [==============================] - 0s 117ms/step - loss: 0.2371 - mae: 0.2371 - val_loss: 0.0556 - val_mae: 0.0556 - lr: 0.0010
# Epoch 16/50
# 4/4 [==============================] - 0s 108ms/step - loss: 0.2363 - mae: 0.2363 - val_loss: 0.0551 - val_mae: 0.0551 - lr: 0.0010
# Epoch 17/50
# 4/4 [==============================] - 0s 104ms/step - loss: 0.2357 - mae: 0.2357 - val_loss: 0.0546 - val_mae: 0.0546 - lr: 0.0010
# Epoch 18/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.2351 - mae: 0.2351 - val_loss: 0.0543 - val_mae: 0.0543 - lr: 0.0010
# Epoch 19/50
# 4/4 [==============================] - 0s 118ms/step - loss: 0.2347 - mae: 0.2347 - val_loss: 0.0540 - val_mae: 0.0540 - lr: 0.0010
# Epoch 20/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2343 - mae: 0.2343 - val_loss: 0.0538 - val_mae: 0.0538 - lr: 0.0010
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2340 - mae: 0.2340
# 4/4 [==============================] - 0s 103ms/step - loss: 0.2340 - mae: 0.2340 - val_loss: 0.0536 - val_mae: 0.0536 - lr: 0.0010
# Epoch 22/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2337 - mae: 0.2337 - val_loss: 0.0534 - val_mae: 0.0534 - lr: 0.0010
# Epoch 23/50
# 4/4 [==============================] - 0s 118ms/step - loss: 0.2335 - mae: 0.2335 - val_loss: 0.0533 - val_mae: 0.0533 - lr: 0.0010
# Epoch 24/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.2333 - mae: 0.2333 - val_loss: 0.0532 - val_mae: 0.0532 - lr: 0.0010
# Epoch 25/50
# 4/4 [==============================] - 0s 112ms/step - loss: 0.2331 - mae: 0.2331 - val_loss: 0.0531 - val_mae: 0.0531 - lr: 0.0010
# Epoch 26/50
# 4/4 [==============================] - 0s 124ms/step - loss: 0.2330 - mae: 0.2330 - val_loss: 0.0529 - val_mae: 0.0529 - lr: 0.0010
# Epoch 27/50
# 4/4 [==============================] - 0s 110ms/step - loss: 0.2328 - mae: 0.2328 - val_loss: 0.0528 - val_mae: 0.0528 - lr: 0.0010
# Epoch 28/50
# 4/4 [==============================] - 0s 110ms/step - loss: 0.2327 - mae: 0.2327 - val_loss: 0.0527 - val_mae: 0.0527 - lr: 0.0010
# Epoch 29/50
# 4/4 [==============================] - 0s 121ms/step - loss: 0.2326 - mae: 0.2326 - val_loss: 0.0526 - val_mae: 0.0526 - lr: 0.0010
# Epoch 30/50
# 4/4 [==============================] - 1s 125ms/step - loss: 0.2325 - mae: 0.2325 - val_loss: 0.0525 - val_mae: 0.0525 - lr: 0.0010
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2324 - mae: 0.2324
# 4/4 [==============================] - 0s 120ms/step - loss: 0.2324 - mae: 0.2324 - val_loss: 0.0524 - val_mae: 0.0524 - lr: 0.0010
# Epoch 32/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2323 - mae: 0.2323 - val_loss: 0.0523 - val_mae: 0.0523 - lr: 0.0010
# Epoch 33/50
# 4/4 [==============================] - 0s 122ms/step - loss: 0.2322 - mae: 0.2322 - val_loss: 0.0523 - val_mae: 0.0523 - lr: 0.0010
# Epoch 34/50
# 4/4 [==============================] - 1s 132ms/step - loss: 0.2321 - mae: 0.2321 - val_loss: 0.0522 - val_mae: 0.0522 - lr: 0.0010
# Epoch 35/50
# 4/4 [==============================] - 0s 108ms/step - loss: 0.2320 - mae: 0.2320 - val_loss: 0.0521 - val_mae: 0.0521 - lr: 0.0010
# Epoch 36/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.2319 - mae: 0.2319 - val_loss: 0.0520 - val_mae: 0.0520 - lr: 0.0010
# Epoch 37/50
# 4/4 [==============================] - 0s 116ms/step - loss: 0.2319 - mae: 0.2319 - val_loss: 0.0520 - val_mae: 0.0520 - lr: 0.0010
# Epoch 38/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.2318 - mae: 0.2318 - val_loss: 0.0519 - val_mae: 0.0519 - lr: 0.0010
# Epoch 39/50
# 4/4 [==============================] - 0s 104ms/step - loss: 0.2317 - mae: 0.2317 - val_loss: 0.0519 - val_mae: 0.0519 - lr: 0.0010
# Epoch 40/50
# 4/4 [==============================] - 0s 119ms/step - loss: 0.2317 - mae: 0.2317 - val_loss: 0.0518 - val_mae: 0.0518 - lr: 0.0010
# Epoch 41/50
# 4/4 [==============================] - ETA: 0s - loss: 0.2316 - mae: 0.2316
# 4/4 [==============================] - 0s 100ms/step - loss: 0.2316 - mae: 0.2316 - val_loss: 0.0518 - val_mae: 0.0518 - lr: 0.0010
# Epoch 42/50
# 4/4 [==============================] - 0s 107ms/step - loss: 0.2315 - mae: 0.2315 - val_loss: 0.0517 - val_mae: 0.0517 - lr: 0.0010
# Epoch 43/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.2315 - mae: 0.2315 - val_loss: 0.0516 - val_mae: 0.0516 - lr: 0.0010
# Epoch 44/50
# 4/4 [==============================] - 0s 108ms/step - loss: 0.2314 - mae: 0.2314 - val_loss: 0.0516 - val_mae: 0.0516 - lr: 0.0010
# Epoch 45/50
# 4/4 [==============================] - 0s 109ms/step - loss: 0.2314 - mae: 0.2314 - val_loss: 0.0516 - val_mae: 0.0516 - lr: 0.0010
# Epoch 46/50
# 4/4 [==============================] - 0s 107ms/step - loss: 0.2313 - mae: 0.2313 - val_loss: 0.0515 - val_mae: 0.0515 - lr: 0.0010
# Epoch 47/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.2313 - mae: 0.2313 - val_loss: 0.0515 - val_mae: 0.0515 - lr: 0.0010
# Epoch 48/50
# 4/4 [==============================] - 0s 134ms/step - loss: 0.2312 - mae: 0.2312 - val_loss: 0.0515 - val_mae: 0.0515 - lr: 0.0010
# Epoch 49/50
# 4/4 [==============================] - 0s 121ms/step - loss: 0.2312 - mae: 0.2312 - val_loss: 0.0514 - val_mae: 0.0514 - lr: 0.0010
# Epoch 50/50
# 4/4 [==============================] - 0s 120ms/step - loss: 0.2311 - mae: 0.2311 - val_loss: 0.0514 - val_mae: 0.0514 - lr: 0.0010
# 2/2 [==============================] - 0s 30ms/step
# WARNING:tensorflow:Layer lstm_87 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       6/Unknown - 2s 72ms/step - loss: 0.3103 - mae: 0.3103
# 6/6 [==============================] - 2s 144ms/step - loss: 0.3103 - mae: 0.3103 - val_loss: 0.3948 - val_mae: 0.3948 - lr: 0.0010
# Epoch 2/50
# 6/6 [==============================] - 1s 99ms/step - loss: 0.2655 - mae: 0.2655 - val_loss: 0.3868 - val_mae: 0.3868 - lr: 0.0010
# Epoch 3/50
# 6/6 [==============================] - 1s 108ms/step - loss: 0.2367 - mae: 0.2367 - val_loss: 0.3709 - val_mae: 0.3709 - lr: 0.0010
# Epoch 4/50
# 6/6 [==============================] - 1s 105ms/step - loss: 0.2209 - mae: 0.2209 - val_loss: 0.3573 - val_mae: 0.3573 - lr: 0.0010
# Epoch 5/50
# 6/6 [==============================] - 1s 107ms/step - loss: 0.2104 - mae: 0.2104 - val_loss: 0.3508 - val_mae: 0.3508 - lr: 0.0010
# Epoch 6/50
# 6/6 [==============================] - 1s 110ms/step - loss: 0.2181 - mae: 0.2181 - val_loss: 0.3430 - val_mae: 0.3430 - lr: 0.0010
# Epoch 7/50
# 6/6 [==============================] - 1s 92ms/step - loss: 0.2053 - mae: 0.2053 - val_loss: 0.3384 - val_mae: 0.3384 - lr: 0.0010
# Epoch 8/50
# 6/6 [==============================] - 1s 96ms/step - loss: 0.1981 - mae: 0.1981 - val_loss: 0.3375 - val_mae: 0.3375 - lr: 0.0010
# Epoch 9/50
# 6/6 [==============================] - 1s 95ms/step - loss: 0.1932 - mae: 0.1932 - val_loss: 0.3430 - val_mae: 0.3430 - lr: 0.0010
# Epoch 10/50
# 6/6 [==============================] - 1s 88ms/step - loss: 0.1936 - mae: 0.1936 - val_loss: 0.3405 - val_mae: 0.3405 - lr: 0.0010
# Epoch 11/50
# 6/6 [==============================] - ETA: 0s - loss: 0.1900 - mae: 0.1900
# 6/6 [==============================] - 1s 105ms/step - loss: 0.1900 - mae: 0.1900 - val_loss: 0.3476 - val_mae: 0.3476 - lr: 0.0010
# Epoch 12/50
# 6/6 [==============================] - 1s 100ms/step - loss: 0.1869 - mae: 0.1869 - val_loss: 0.3455 - val_mae: 0.3455 - lr: 0.0010
# Epoch 13/50
# 6/6 [==============================] - 1s 94ms/step - loss: 0.1879 - mae: 0.1879 - val_loss: 0.3502 - val_mae: 0.3502 - lr: 0.0010
# Epoch 14/50
# 6/6 [==============================] - 1s 93ms/step - loss: 0.1821 - mae: 0.1821 - val_loss: 0.3516 - val_mae: 0.3516 - lr: 0.0010
# Epoch 15/50
# 6/6 [==============================] - 1s 104ms/step - loss: 0.1808 - mae: 0.1808 - val_loss: 0.3482 - val_mae: 0.3482 - lr: 0.0010
# Epoch 16/50
# 6/6 [==============================] - 1s 92ms/step - loss: 0.1797 - mae: 0.1797 - val_loss: 0.3476 - val_mae: 0.3476 - lr: 0.0010
# Epoch 17/50
# 6/6 [==============================] - 1s 86ms/step - loss: 0.1788 - mae: 0.1788 - val_loss: 0.3509 - val_mae: 0.3509 - lr: 0.0010
# Epoch 18/50
# 6/6 [==============================] - 1s 85ms/step - loss: 0.1781 - mae: 0.1781 - val_loss: 0.3523 - val_mae: 0.3523 - lr: 0.0010
# Epoch 19/50
# 6/6 [==============================] - 1s 93ms/step - loss: 0.1773 - mae: 0.1773 - val_loss: 0.3522 - val_mae: 0.3522 - lr: 1.0000e-04
# Epoch 20/50
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1772 - mae: 0.1772 - val_loss: 0.3521 - val_mae: 0.3521 - lr: 1.0000e-04
# Epoch 21/50
# 6/6 [==============================] - ETA: 0s - loss: 0.1772 - mae: 0.1772
# 6/6 [==============================] - 1s 100ms/step - loss: 0.1772 - mae: 0.1772 - val_loss: 0.3519 - val_mae: 0.3519 - lr: 1.0000e-04
# Epoch 22/50
# 6/6 [==============================] - 1s 109ms/step - loss: 0.1771 - mae: 0.1771 - val_loss: 0.3518 - val_mae: 0.3518 - lr: 1.0000e-04
# Epoch 23/50
# 6/6 [==============================] - 1s 101ms/step - loss: 0.1770 - mae: 0.1770 - val_loss: 0.3517 - val_mae: 0.3517 - lr: 1.0000e-04
# Epoch 24/50
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1770 - mae: 0.1770 - val_loss: 0.3515 - val_mae: 0.3515 - lr: 1.0000e-04
# Epoch 25/50
# 6/6 [==============================] - 1s 106ms/step - loss: 0.1769 - mae: 0.1769 - val_loss: 0.3514 - val_mae: 0.3514 - lr: 1.0000e-04
# Epoch 26/50
# 6/6 [==============================] - 1s 94ms/step - loss: 0.1768 - mae: 0.1768 - val_loss: 0.3512 - val_mae: 0.3512 - lr: 1.0000e-04
# Epoch 27/50
# 6/6 [==============================] - 1s 95ms/step - loss: 0.1768 - mae: 0.1768 - val_loss: 0.3509 - val_mae: 0.3509 - lr: 1.0000e-04
# Epoch 28/50
# 6/6 [==============================] - 1s 106ms/step - loss: 0.1767 - mae: 0.1767 - val_loss: 0.3506 - val_mae: 0.3506 - lr: 1.0000e-04
# 2/2 [==============================] - 0s 34ms/step
# WARNING:tensorflow:Layer lstm_88 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       7/Unknown - 2s 81ms/step - loss: 0.2245 - mae: 0.2245
# 7/7 [==============================] - 2s 147ms/step - loss: 0.2245 - mae: 0.2245 - val_loss: 0.1050 - val_mae: 0.1050 - lr: 0.0010
# Epoch 2/50
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2066 - mae: 0.2066 - val_loss: 0.0949 - val_mae: 0.0949 - lr: 0.0010
# Epoch 3/50
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1976 - mae: 0.1976 - val_loss: 0.0871 - val_mae: 0.0871 - lr: 0.0010
# Epoch 4/50
# 7/7 [==============================] - 1s 90ms/step - loss: 0.1909 - mae: 0.1909 - val_loss: 0.0809 - val_mae: 0.0809 - lr: 0.0010
# Epoch 5/50
# 7/7 [==============================] - 1s 89ms/step - loss: 0.1856 - mae: 0.1856 - val_loss: 0.0757 - val_mae: 0.0757 - lr: 0.0010
# Epoch 6/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.1813 - mae: 0.1813 - val_loss: 0.0716 - val_mae: 0.0716 - lr: 0.0010
# Epoch 7/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.1780 - mae: 0.1780 - val_loss: 0.0682 - val_mae: 0.0682 - lr: 0.0010
# Epoch 8/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1754 - mae: 0.1754 - val_loss: 0.0655 - val_mae: 0.0655 - lr: 0.0010
# Epoch 9/50
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1733 - mae: 0.1733 - val_loss: 0.0634 - val_mae: 0.0634 - lr: 0.0010
# Epoch 10/50
# 7/7 [==============================] - 1s 118ms/step - loss: 0.1717 - mae: 0.1717 - val_loss: 0.0616 - val_mae: 0.0616 - lr: 0.0010
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1704 - mae: 0.1704
# 7/7 [==============================] - 1s 108ms/step - loss: 0.1704 - mae: 0.1704 - val_loss: 0.0602 - val_mae: 0.0602 - lr: 0.0010
# Epoch 12/50
# 7/7 [==============================] - 1s 101ms/step - loss: 0.1694 - mae: 0.1694 - val_loss: 0.0591 - val_mae: 0.0591 - lr: 0.0010
# Epoch 13/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1686 - mae: 0.1686 - val_loss: 0.0583 - val_mae: 0.0583 - lr: 0.0010
# Epoch 14/50
# 7/7 [==============================] - 1s 93ms/step - loss: 0.1679 - mae: 0.1679 - val_loss: 0.0577 - val_mae: 0.0577 - lr: 0.0010
# Epoch 15/50
# 7/7 [==============================] - 1s 100ms/step - loss: 0.1673 - mae: 0.1673 - val_loss: 0.0572 - val_mae: 0.0572 - lr: 0.0010
# Epoch 16/50
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1669 - mae: 0.1669 - val_loss: 0.0568 - val_mae: 0.0568 - lr: 0.0010
# Epoch 17/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.1665 - mae: 0.1665 - val_loss: 0.0565 - val_mae: 0.0565 - lr: 0.0010
# Epoch 18/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1662 - mae: 0.1662 - val_loss: 0.0562 - val_mae: 0.0562 - lr: 0.0010
# Epoch 19/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.1659 - mae: 0.1659 - val_loss: 0.0560 - val_mae: 0.0560 - lr: 0.0010
# Epoch 20/50
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1656 - mae: 0.1656 - val_loss: 0.0558 - val_mae: 0.0558 - lr: 0.0010
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1654 - mae: 0.1654
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1654 - mae: 0.1654 - val_loss: 0.0556 - val_mae: 0.0556 - lr: 0.0010
# Epoch 22/50
# 7/7 [==============================] - 1s 102ms/step - loss: 0.1652 - mae: 0.1652 - val_loss: 0.0555 - val_mae: 0.0555 - lr: 0.0010
# Epoch 23/50
# 7/7 [==============================] - 1s 91ms/step - loss: 0.1650 - mae: 0.1650 - val_loss: 0.0553 - val_mae: 0.0553 - lr: 0.0010
# Epoch 24/50
# 7/7 [==============================] - 1s 100ms/step - loss: 0.1649 - mae: 0.1649 - val_loss: 0.0552 - val_mae: 0.0552 - lr: 0.0010
# Epoch 25/50
# 7/7 [==============================] - 1s 90ms/step - loss: 0.1648 - mae: 0.1648 - val_loss: 0.0551 - val_mae: 0.0551 - lr: 0.0010
# Epoch 26/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.1646 - mae: 0.1646 - val_loss: 0.0551 - val_mae: 0.0551 - lr: 0.0010
# Epoch 27/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.1645 - mae: 0.1645 - val_loss: 0.0550 - val_mae: 0.0550 - lr: 0.0010
# Epoch 28/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1644 - mae: 0.1644 - val_loss: 0.0550 - val_mae: 0.0550 - lr: 0.0010
# Epoch 29/50
# 7/7 [==============================] - 1s 100ms/step - loss: 0.1643 - mae: 0.1643 - val_loss: 0.0549 - val_mae: 0.0549 - lr: 0.0010
# Epoch 30/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.1643 - mae: 0.1643 - val_loss: 0.0549 - val_mae: 0.0549 - lr: 0.0010
# Epoch 31/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1642 - mae: 0.1642
# 7/7 [==============================] - 1s 92ms/step - loss: 0.1642 - mae: 0.1642 - val_loss: 0.0548 - val_mae: 0.0548 - lr: 0.0010
# Epoch 32/50
# 7/7 [==============================] - 1s 87ms/step - loss: 0.1641 - mae: 0.1641 - val_loss: 0.0548 - val_mae: 0.0548 - lr: 0.0010
# Epoch 33/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.1641 - mae: 0.1641 - val_loss: 0.0548 - val_mae: 0.0548 - lr: 0.0010
# Epoch 34/50
# 7/7 [==============================] - 1s 95ms/step - loss: 0.1640 - mae: 0.1640 - val_loss: 0.0548 - val_mae: 0.0548 - lr: 0.0010
# Epoch 35/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.1640 - mae: 0.1640 - val_loss: 0.0548 - val_mae: 0.0548 - lr: 0.0010
# Epoch 36/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.1639 - mae: 0.1639 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 37/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.1639 - mae: 0.1639 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 38/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.1638 - mae: 0.1638 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 39/50
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1638 - mae: 0.1638 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 40/50
# 7/7 [==============================] - 1s 92ms/step - loss: 0.1638 - mae: 0.1638 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 41/50
# 7/7 [==============================] - ETA: 0s - loss: 0.1637 - mae: 0.1637
# 7/7 [==============================] - 1s 84ms/step - loss: 0.1637 - mae: 0.1637 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 42/50
# 7/7 [==============================] - 1s 89ms/step - loss: 0.1637 - mae: 0.1637 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 43/50
# 7/7 [==============================] - 1s 87ms/step - loss: 0.1637 - mae: 0.1637 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 44/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1636 - mae: 0.1636 - val_loss: 0.0546 - val_mae: 0.0546 - lr: 0.0010
# Epoch 45/50
# 7/7 [==============================] - 1s 102ms/step - loss: 0.1636 - mae: 0.1636 - val_loss: 0.0547 - val_mae: 0.0547 - lr: 0.0010
# Epoch 46/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1636 - mae: 0.1636 - val_loss: 0.0546 - val_mae: 0.0546 - lr: 0.0010
# Epoch 47/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.1636 - mae: 0.1636 - val_loss: 0.0546 - val_mae: 0.0546 - lr: 0.0010
# Epoch 48/50
# 7/7 [==============================] - 1s 105ms/step - loss: 0.1635 - mae: 0.1635 - val_loss: 0.0546 - val_mae: 0.0546 - lr: 0.0010
# Epoch 49/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.1635 - mae: 0.1635 - val_loss: 0.0546 - val_mae: 0.0546 - lr: 0.0010
# Epoch 50/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.1635 - mae: 0.1635 - val_loss: 0.0546 - val_mae: 0.0546 - lr: 0.0010
# 2/2 [==============================] - 0s 40ms/step
# WARNING:tensorflow:Layer lstm_89 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       9/Unknown - 2s 81ms/step - loss: 0.2144 - mae: 0.2144
# 9/9 [==============================] - 2s 128ms/step - loss: 0.2144 - mae: 0.2144 - val_loss: 0.2090 - val_mae: 0.2090 - lr: 0.0010
# Epoch 2/50
# 9/9 [==============================] - 1s 95ms/step - loss: 0.1825 - mae: 0.1825 - val_loss: 0.1973 - val_mae: 0.1973 - lr: 0.0010
# Epoch 3/50
# 9/9 [==============================] - 1s 102ms/step - loss: 0.1709 - mae: 0.1709 - val_loss: 0.1891 - val_mae: 0.1891 - lr: 0.0010
# Epoch 4/50
# 9/9 [==============================] - 1s 94ms/step - loss: 0.1629 - mae: 0.1629 - val_loss: 0.1830 - val_mae: 0.1830 - lr: 0.0010
# Epoch 5/50
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1570 - mae: 0.1570 - val_loss: 0.1786 - val_mae: 0.1786 - lr: 0.0010
# Epoch 6/50
# 9/9 [==============================] - 1s 91ms/step - loss: 0.1527 - mae: 0.1527 - val_loss: 0.1758 - val_mae: 0.1758 - lr: 0.0010
# Epoch 7/50
# 9/9 [==============================] - 1s 90ms/step - loss: 0.1498 - mae: 0.1498 - val_loss: 0.1739 - val_mae: 0.1739 - lr: 0.0010
# Epoch 8/50
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1478 - mae: 0.1478 - val_loss: 0.1726 - val_mae: 0.1726 - lr: 0.0010
# Epoch 9/50
# 9/9 [==============================] - 1s 105ms/step - loss: 0.1465 - mae: 0.1465 - val_loss: 0.1716 - val_mae: 0.1716 - lr: 0.0010
# Epoch 10/50
# 9/9 [==============================] - 1s 94ms/step - loss: 0.1456 - mae: 0.1456 - val_loss: 0.1709 - val_mae: 0.1709 - lr: 0.0010
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1449 - mae: 0.1449
# 9/9 [==============================] - 1s 100ms/step - loss: 0.1449 - mae: 0.1449 - val_loss: 0.1702 - val_mae: 0.1702 - lr: 0.0010
# Epoch 12/50
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1444 - mae: 0.1444 - val_loss: 0.1696 - val_mae: 0.1696 - lr: 0.0010
# Epoch 13/50
# 9/9 [==============================] - 1s 96ms/step - loss: 0.1440 - mae: 0.1440 - val_loss: 0.1690 - val_mae: 0.1690 - lr: 0.0010
# Epoch 14/50
# 9/9 [==============================] - 1s 94ms/step - loss: 0.1437 - mae: 0.1437 - val_loss: 0.1685 - val_mae: 0.1685 - lr: 0.0010
# Epoch 15/50
# 9/9 [==============================] - 1s 92ms/step - loss: 0.1434 - mae: 0.1434 - val_loss: 0.1681 - val_mae: 0.1681 - lr: 0.0010
# Epoch 16/50
# 9/9 [==============================] - 1s 89ms/step - loss: 0.1432 - mae: 0.1432 - val_loss: 0.1677 - val_mae: 0.1677 - lr: 0.0010
# Epoch 17/50
# 9/9 [==============================] - 1s 88ms/step - loss: 0.1430 - mae: 0.1430 - val_loss: 0.1674 - val_mae: 0.1674 - lr: 0.0010
# Epoch 18/50
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1428 - mae: 0.1428 - val_loss: 0.1671 - val_mae: 0.1671 - lr: 0.0010
# Epoch 19/50
# 9/9 [==============================] - 1s 90ms/step - loss: 0.1426 - mae: 0.1426 - val_loss: 0.1669 - val_mae: 0.1669 - lr: 0.0010
# Epoch 20/50
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1425 - mae: 0.1425 - val_loss: 0.1667 - val_mae: 0.1667 - lr: 0.0010
# Epoch 21/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1424 - mae: 0.1424
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1424 - mae: 0.1424 - val_loss: 0.1666 - val_mae: 0.1666 - lr: 0.0010
# Epoch 22/50
# 9/9 [==============================] - 1s 93ms/step - loss: 0.1423 - mae: 0.1423 - val_loss: 0.1665 - val_mae: 0.1665 - lr: 0.0010
# Epoch 23/50
# 9/9 [==============================] - 1s 87ms/step - loss: 0.1422 - mae: 0.1422 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 0.0010
# Epoch 24/50
# 9/9 [==============================] - 1s 88ms/step - loss: 0.1422 - mae: 0.1422 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 0.0010
# Epoch 25/50
# 9/9 [==============================] - 1s 87ms/step - loss: 0.1421 - mae: 0.1421 - val_loss: 0.1663 - val_mae: 0.1663 - lr: 0.0010
# Epoch 26/50
# 9/9 [==============================] - 1s 90ms/step - loss: 0.1420 - mae: 0.1420 - val_loss: 0.1663 - val_mae: 0.1663 - lr: 0.0010
# Epoch 27/50
# 9/9 [==============================] - 1s 90ms/step - loss: 0.1420 - mae: 0.1420 - val_loss: 0.1663 - val_mae: 0.1663 - lr: 0.0010
# Epoch 28/50
# 9/9 [==============================] - 1s 87ms/step - loss: 0.1419 - mae: 0.1419 - val_loss: 0.1663 - val_mae: 0.1663 - lr: 0.0010
# Epoch 29/50
# 9/9 [==============================] - 1s 92ms/step - loss: 0.1419 - mae: 0.1419 - val_loss: 0.1663 - val_mae: 0.1663 - lr: 0.0010
# Epoch 30/50
# 9/9 [==============================] - 1s 93ms/step - loss: 0.1418 - mae: 0.1418 - val_loss: 0.1663 - val_mae: 0.1663 - lr: 0.0010
# Epoch 31/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1418 - mae: 0.1418
# 9/9 [==============================] - 1s 88ms/step - loss: 0.1418 - mae: 0.1418 - val_loss: 0.1663 - val_mae: 0.1663 - lr: 0.0010
# Epoch 32/50
# 9/9 [==============================] - 1s 91ms/step - loss: 0.1418 - mae: 0.1418 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 0.0010
# Epoch 33/50
# 9/9 [==============================] - 1s 89ms/step - loss: 0.1417 - mae: 0.1417 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 0.0010
# Epoch 34/50
# 9/9 [==============================] - 1s 87ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 35/50
# 9/9 [==============================] - 1s 95ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 36/50
# 9/9 [==============================] - 1s 89ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 37/50
# 9/9 [==============================] - 1s 77ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 38/50
# 9/9 [==============================] - 1s 98ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 39/50
# 9/9 [==============================] - 1s 88ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 40/50
# 9/9 [==============================] - 1s 88ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 41/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1414 - mae: 0.1414
# 9/9 [==============================] - 1s 85ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 42/50
# 9/9 [==============================] - 1s 87ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 43/50
# 9/9 [==============================] - 1s 91ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-04
# Epoch 44/50
# 9/9 [==============================] - 1s 89ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-05
# Epoch 45/50
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-05
# Epoch 46/50
# 9/9 [==============================] - 1s 88ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-05
# Epoch 47/50
# 9/9 [==============================] - 1s 81ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-05
# Epoch 48/50
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1414 - mae: 0.1414 - val_loss: 0.1664 - val_mae: 0.1664 - lr: 1.0000e-05
# 2/2 [==============================] - 1s 38ms/step
# 2 번째 노은동 지역의 미세먼지 예측을 시작하겠습니다.
# WARNING:tensorflow:Layer lstm_90 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       2/Unknown - 1s 70ms/step - loss: 0.0975 - mae: 0.0975
# 2/2 [==============================] - 2s 433ms/step - loss: 0.0975 - mae: 0.0975 - val_loss: 0.0982 - val_mae: 0.0982 - lr: 0.0010
# Epoch 2/50
# 2/2 [==============================] - 0s 215ms/step - loss: 0.0920 - mae: 0.0920 - val_loss: 0.0943 - val_mae: 0.0943 - lr: 0.0010
# Epoch 3/50
# 2/2 [==============================] - 0s 221ms/step - loss: 0.0882 - mae: 0.0882 - val_loss: 0.0913 - val_mae: 0.0913 - lr: 0.0010
# Epoch 4/50
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0856 - mae: 0.0856 - val_loss: 0.0886 - val_mae: 0.0886 - lr: 0.0010
# Epoch 5/50
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0833 - mae: 0.0833 - val_loss: 0.0863 - val_mae: 0.0863 - lr: 0.0010
# Epoch 6/50
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0814 - mae: 0.0814 - val_loss: 0.0841 - val_mae: 0.0841 - lr: 0.0010
# Epoch 7/50
# 2/2 [==============================] - 0s 220ms/step - loss: 0.0797 - mae: 0.0797 - val_loss: 0.0820 - val_mae: 0.0820 - lr: 0.0010
# Epoch 8/50
# 2/2 [==============================] - 0s 292ms/step - loss: 0.0782 - mae: 0.0782 - val_loss: 0.0802 - val_mae: 0.0802 - lr: 0.0010
# Epoch 9/50
# 2/2 [==============================] - 0s 206ms/step - loss: 0.0767 - mae: 0.0767 - val_loss: 0.0785 - val_mae: 0.0785 - lr: 0.0010
# Epoch 10/50
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0755 - mae: 0.0755 - val_loss: 0.0770 - val_mae: 0.0770 - lr: 0.0010
# Epoch 11/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0744 - mae: 0.0744
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0744 - mae: 0.0744 - val_loss: 0.0755 - val_mae: 0.0755 - lr: 0.0010
# Epoch 12/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0733 - mae: 0.0733 - val_loss: 0.0742 - val_mae: 0.0742 - lr: 0.0010
# Epoch 13/50
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0724 - mae: 0.0724 - val_loss: 0.0730 - val_mae: 0.0730 - lr: 0.0010
# Epoch 14/50
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0715 - mae: 0.0715 - val_loss: 0.0718 - val_mae: 0.0718 - lr: 0.0010
# Epoch 15/50
# 2/2 [==============================] - 0s 195ms/step - loss: 0.0707 - mae: 0.0707 - val_loss: 0.0708 - val_mae: 0.0708 - lr: 0.0010
# Epoch 16/50
# 2/2 [==============================] - 0s 206ms/step - loss: 0.0699 - mae: 0.0699 - val_loss: 0.0698 - val_mae: 0.0698 - lr: 0.0010
# Epoch 17/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0692 - mae: 0.0692 - val_loss: 0.0689 - val_mae: 0.0689 - lr: 0.0010
# Epoch 18/50
# 2/2 [==============================] - 0s 206ms/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.0680 - val_mae: 0.0680 - lr: 0.0010
# Epoch 19/50
# 2/2 [==============================] - 0s 211ms/step - loss: 0.0681 - mae: 0.0681 - val_loss: 0.0672 - val_mae: 0.0672 - lr: 0.0010
# Epoch 20/50
# 2/2 [==============================] - 0s 199ms/step - loss: 0.0675 - mae: 0.0675 - val_loss: 0.0665 - val_mae: 0.0665 - lr: 0.0010
# Epoch 21/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0669 - mae: 0.0669
# 2/2 [==============================] - 0s 227ms/step - loss: 0.0669 - mae: 0.0669 - val_loss: 0.0658 - val_mae: 0.0658 - lr: 0.0010
# Epoch 22/50
# 2/2 [==============================] - 0s 209ms/step - loss: 0.0665 - mae: 0.0665 - val_loss: 0.0653 - val_mae: 0.0653 - lr: 0.0010
# Epoch 23/50
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0661 - mae: 0.0661 - val_loss: 0.0647 - val_mae: 0.0647 - lr: 0.0010
# Epoch 24/50
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0657 - mae: 0.0657 - val_loss: 0.0642 - val_mae: 0.0642 - lr: 0.0010
# Epoch 25/50
# 2/2 [==============================] - 0s 202ms/step - loss: 0.0653 - mae: 0.0653 - val_loss: 0.0638 - val_mae: 0.0638 - lr: 0.0010
# Epoch 26/50
# 2/2 [==============================] - 0s 204ms/step - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0634 - val_mae: 0.0634 - lr: 0.0010
# Epoch 27/50
# 2/2 [==============================] - 0s 213ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0630 - val_mae: 0.0630 - lr: 0.0010
# Epoch 28/50
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0646 - mae: 0.0646 - val_loss: 0.0627 - val_mae: 0.0627 - lr: 0.0010
# Epoch 29/50
# 2/2 [==============================] - 0s 207ms/step - loss: 0.0643 - mae: 0.0643 - val_loss: 0.0624 - val_mae: 0.0624 - lr: 0.0010
# Epoch 30/50
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0641 - mae: 0.0641 - val_loss: 0.0622 - val_mae: 0.0622 - lr: 0.0010
# Epoch 31/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0639 - mae: 0.0639
# 2/2 [==============================] - 0s 201ms/step - loss: 0.0639 - mae: 0.0639 - val_loss: 0.0620 - val_mae: 0.0620 - lr: 0.0010
# Epoch 32/50
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0637 - mae: 0.0637 - val_loss: 0.0617 - val_mae: 0.0617 - lr: 0.0010
# Epoch 33/50
# 2/2 [==============================] - 0s 242ms/step - loss: 0.0635 - mae: 0.0635 - val_loss: 0.0615 - val_mae: 0.0615 - lr: 0.0010
# Epoch 34/50
# 2/2 [==============================] - 0s 195ms/step - loss: 0.0633 - mae: 0.0633 - val_loss: 0.0614 - val_mae: 0.0614 - lr: 0.0010
# Epoch 35/50
# 2/2 [==============================] - 0s 216ms/step - loss: 0.0631 - mae: 0.0631 - val_loss: 0.0612 - val_mae: 0.0612 - lr: 0.0010
# Epoch 36/50
# 2/2 [==============================] - 0s 200ms/step - loss: 0.0630 - mae: 0.0630 - val_loss: 0.0610 - val_mae: 0.0610 - lr: 0.0010
# Epoch 37/50
# 2/2 [==============================] - 0s 210ms/step - loss: 0.0628 - mae: 0.0628 - val_loss: 0.0609 - val_mae: 0.0609 - lr: 0.0010
# Epoch 38/50
# 2/2 [==============================] - 0s 217ms/step - loss: 0.0627 - mae: 0.0627 - val_loss: 0.0607 - val_mae: 0.0607 - lr: 0.0010
# Epoch 39/50
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0625 - mae: 0.0625 - val_loss: 0.0606 - val_mae: 0.0606 - lr: 0.0010
# Epoch 40/50
# 2/2 [==============================] - 0s 209ms/step - loss: 0.0624 - mae: 0.0624 - val_loss: 0.0605 - val_mae: 0.0605 - lr: 0.0010
# Epoch 41/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0623 - mae: 0.0623
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0623 - mae: 0.0623 - val_loss: 0.0603 - val_mae: 0.0603 - lr: 0.0010
# Epoch 42/50
# 2/2 [==============================] - 0s 216ms/step - loss: 0.0621 - mae: 0.0621 - val_loss: 0.0602 - val_mae: 0.0602 - lr: 0.0010
# Epoch 43/50
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0620 - mae: 0.0620 - val_loss: 0.0601 - val_mae: 0.0601 - lr: 0.0010
# Epoch 44/50
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0619 - mae: 0.0619 - val_loss: 0.0600 - val_mae: 0.0600 - lr: 0.0010
# Epoch 45/50
# 2/2 [==============================] - 0s 204ms/step - loss: 0.0619 - mae: 0.0619 - val_loss: 0.0600 - val_mae: 0.0600 - lr: 0.0010
# Epoch 46/50
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0617 - mae: 0.0617 - val_loss: 0.0599 - val_mae: 0.0599 - lr: 0.0010
# Epoch 47/50
# 2/2 [==============================] - 0s 210ms/step - loss: 0.0616 - mae: 0.0616 - val_loss: 0.0599 - val_mae: 0.0599 - lr: 0.0010
# Epoch 48/50
# 2/2 [==============================] - 0s 211ms/step - loss: 0.0615 - mae: 0.0615 - val_loss: 0.0599 - val_mae: 0.0599 - lr: 0.0010
# Epoch 49/50
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0614 - mae: 0.0614 - val_loss: 0.0597 - val_mae: 0.0597 - lr: 0.0010
# Epoch 50/50
# 2/2 [==============================] - 0s 209ms/step - loss: 0.0613 - mae: 0.0613 - val_loss: 0.0597 - val_mae: 0.0597 - lr: 0.0010
# 2/2 [==============================] - 0s 40ms/step
# WARNING:tensorflow:Layer lstm_91 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       4/Unknown - 2s 75ms/step - loss: 0.4211 - mae: 0.4211
# 4/4 [==============================] - 2s 195ms/step - loss: 0.4211 - mae: 0.4211 - val_loss: 0.0910 - val_mae: 0.0910 - lr: 0.0010
# Epoch 2/50
# 4/4 [==============================] - 0s 110ms/step - loss: 0.3460 - mae: 0.3460 - val_loss: 0.0852 - val_mae: 0.0852 - lr: 0.0010
# Epoch 3/50
# 4/4 [==============================] - 0s 122ms/step - loss: 0.2898 - mae: 0.2898 - val_loss: 0.0809 - val_mae: 0.0809 - lr: 0.0010
# Epoch 4/50
# 4/4 [==============================] - 0s 121ms/step - loss: 0.2180 - mae: 0.2180 - val_loss: 0.0774 - val_mae: 0.0774 - lr: 0.0010
# Epoch 5/50
# 4/4 [==============================] - 0s 120ms/step - loss: 0.2465 - mae: 0.2465 - val_loss: 0.0749 - val_mae: 0.0749 - lr: 0.0010
# Epoch 6/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.1617 - mae: 0.1617 - val_loss: 0.0726 - val_mae: 0.0726 - lr: 0.0010
# Epoch 7/50
# 4/4 [==============================] - 0s 112ms/step - loss: 0.1859 - mae: 0.1859 - val_loss: 0.0710 - val_mae: 0.0710 - lr: 0.0010
# Epoch 8/50
# 4/4 [==============================] - 0s 101ms/step - loss: 0.1903 - mae: 0.1903 - val_loss: 0.0694 - val_mae: 0.0694 - lr: 0.0010
# Epoch 9/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1359 - mae: 0.1359 - val_loss: 0.0680 - val_mae: 0.0680 - lr: 0.0010
# Epoch 10/50
# 4/4 [==============================] - 0s 121ms/step - loss: 0.1099 - mae: 0.1099 - val_loss: 0.0670 - val_mae: 0.0670 - lr: 0.0010
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0971 - mae: 0.0971
# 4/4 [==============================] - 0s 102ms/step - loss: 0.0971 - mae: 0.0971 - val_loss: 0.0662 - val_mae: 0.0662 - lr: 0.0010
# Epoch 12/50
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0897 - mae: 0.0897 - val_loss: 0.0656 - val_mae: 0.0656 - lr: 0.0010
# Epoch 13/50
# 4/4 [==============================] - 0s 109ms/step - loss: 0.1497 - mae: 0.1497 - val_loss: 0.0654 - val_mae: 0.0654 - lr: 0.0010
# Epoch 14/50
# 4/4 [==============================] - 0s 96ms/step - loss: 0.1015 - mae: 0.1015 - val_loss: 0.0650 - val_mae: 0.0650 - lr: 0.0010
# Epoch 15/50
# 4/4 [==============================] - 0s 105ms/step - loss: 0.0854 - mae: 0.0854 - val_loss: 0.0647 - val_mae: 0.0647 - lr: 0.0010
# Epoch 16/50
# 4/4 [==============================] - 0s 106ms/step - loss: 0.0793 - mae: 0.0793 - val_loss: 0.0644 - val_mae: 0.0644 - lr: 0.0010
# Epoch 17/50
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0761 - mae: 0.0761 - val_loss: 0.0643 - val_mae: 0.0643 - lr: 0.0010
# Epoch 18/50
# 4/4 [==============================] - 0s 99ms/step - loss: 0.0737 - mae: 0.0737 - val_loss: 0.0642 - val_mae: 0.0642 - lr: 0.0010
# Epoch 19/50
# 4/4 [==============================] - 0s 104ms/step - loss: 0.0718 - mae: 0.0718 - val_loss: 0.0641 - val_mae: 0.0641 - lr: 0.0010
# Epoch 20/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0702 - mae: 0.0702 - val_loss: 0.0641 - val_mae: 0.0641 - lr: 0.0010
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0689 - mae: 0.0689
# 4/4 [==============================] - 0s 123ms/step - loss: 0.0689 - mae: 0.0689 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 22/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0679 - mae: 0.0679 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 23/50
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0671 - mae: 0.0671 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 24/50
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0663 - mae: 0.0663 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 25/50
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0658 - mae: 0.0658 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 26/50
# 4/4 [==============================] - 1s 120ms/step - loss: 0.0652 - mae: 0.0652 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 27/50
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0648 - mae: 0.0648 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 28/50
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0645 - mae: 0.0645 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 29/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0641 - mae: 0.0641 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 30/50
# 4/4 [==============================] - 0s 102ms/step - loss: 0.0639 - mae: 0.0639 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 0.0636 - mae: 0.0636
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0636 - mae: 0.0636 - val_loss: 0.0640 - val_mae: 0.0640 - lr: 0.0010
# ...
# Epoch 4/50
# 6/6 [==============================] - 1s 99ms/step - loss: 0.1039 - mae: 0.1039 - val_loss: 0.3733 - val_mae: 0.3733 - lr: 0.0010
# Epoch 5/50
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0987 - mae: 0.0987 - val_loss: 0.3706 - val_mae: 0.3706 - lr: 0.0010
# Epoch 6/50
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0948 - mae: 0.0948 - val_loss: 0.3690 - val_mae: 0.3690 - lr: 0.0010
# Epoch 7/50
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0918 - mae: 0.0918 - val_loss: 0.3681 - val_mae: 0.3681 - lr: 0.0010
# Epoch 8/50
# 6/6 [==============================] - 1s 95ms/step - loss: 0.0895 - mae: 0.0895 - val_loss: 0.3676 - val_mae: 0.3676 - lr: 0.0010
# Epoch 9/50
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0877 - mae: 0.0877 - val_loss: 0.3675 - val_mae: 0.3675 - lr: 0.0010
# Epoch 10/50
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0863 - mae: 0.0863 - val_loss: 0.3675 - val_mae: 0.3675 - lr: 0.0010
# Epoch 11/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0852 - mae: 0.0852
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0852 - mae: 0.0852 - val_loss: 0.3675 - val_mae: 0.3675 - lr: 0.0010
# Epoch 12/50
# 6/6 [==============================] - 1s 94ms/step - loss: 0.0842 - mae: 0.0842 - val_loss: 0.3677 - val_mae: 0.3677 - lr: 0.0010
# Epoch 13/50
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0834 - mae: 0.0834 - val_loss: 0.3679 - val_mae: 0.3679 - lr: 0.0010
# Epoch 14/50
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0828 - mae: 0.0828 - val_loss: 0.3681 - val_mae: 0.3681 - lr: 0.0010
# Epoch 15/50
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0823 - mae: 0.0823 - val_loss: 0.3684 - val_mae: 0.3684 - lr: 0.0010
# Epoch 16/50
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0818 - mae: 0.0818 - val_loss: 0.3685 - val_mae: 0.3685 - lr: 0.0010
# Epoch 17/50
# 6/6 [==============================] - 1s 95ms/step - loss: 0.0814 - mae: 0.0814 - val_loss: 0.3688 - val_mae: 0.3688 - lr: 0.0010
# Epoch 18/50
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0810 - mae: 0.0810 - val_loss: 0.3689 - val_mae: 0.3689 - lr: 0.0010
# Epoch 19/50
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0808 - mae: 0.0808 - val_loss: 0.3691 - val_mae: 0.3691 - lr: 0.0010
# Epoch 20/50
# 6/6 [==============================] - 1s 90ms/step - loss: 0.0804 - mae: 0.0804 - val_loss: 0.3691 - val_mae: 0.3691 - lr: 1.0000e-04
# Epoch 21/50
# 6/6 [==============================] - ETA: 0s - loss: 0.0803 - mae: 0.0803
# 6/6 [==============================] - 1s 95ms/step - loss: 0.0803 - mae: 0.0803 - val_loss: 0.3691 - val_mae: 0.3691 - lr: 1.0000e-04
# Epoch 22/50
# 6/6 [==============================] - 1s 101ms/step - loss: 0.0803 - mae: 0.0803 - val_loss: 0.3691 - val_mae: 0.3691 - lr: 1.0000e-04
# Epoch 23/50
# 6/6 [==============================] - 1s 115ms/step - loss: 0.0802 - mae: 0.0802 - val_loss: 0.3690 - val_mae: 0.3690 - lr: 1.0000e-04
# Epoch 24/50
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0802 - mae: 0.0802 - val_loss: 0.3690 - val_mae: 0.3690 - lr: 1.0000e-04
# Epoch 25/50
# 6/6 [==============================] - 1s 103ms/step - loss: 0.0802 - mae: 0.0802 - val_loss: 0.3690 - val_mae: 0.3690 - lr: 1.0000e-04
# Epoch 26/50
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0801 - mae: 0.0801 - val_loss: 0.3690 - val_mae: 0.3690 - lr: 1.0000e-04
# Epoch 27/50
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0801 - mae: 0.0801 - val_loss: 0.3690 - val_mae: 0.3690 - lr: 1.0000e-04
# Epoch 28/50
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0801 - mae: 0.0801 - val_loss: 0.3690 - val_mae: 0.3690 - lr: 1.0000e-04
# Epoch 29/50
# 6/6 [==============================] - 1s 88ms/step - loss: 0.0800 - mae: 0.0800 - val_loss: 0.3690 - val_mae: 0.3690 - lr: 1.0000e-04
# 2/2 [==============================] - 0s 39ms/step
# WARNING:tensorflow:Layer lstm_168 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       7/Unknown - 2s 80ms/step - loss: 0.7380 - mae: 0.7380
# 7/7 [==============================] - 2s 137ms/step - loss: 0.7380 - mae: 0.7380 - val_loss: 0.1028 - val_mae: 0.1028 - lr: 0.0010
# Epoch 2/50
# 7/7 [==============================] - 1s 92ms/step - loss: 0.6308 - mae: 0.6308 - val_loss: 0.0944 - val_mae: 0.0944 - lr: 0.0010
# Epoch 3/50
# 7/7 [==============================] - 1s 89ms/step - loss: 0.5037 - mae: 0.5037 - val_loss: 0.0880 - val_mae: 0.0880 - lr: 0.0010
# Epoch 4/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3336 - mae: 0.3336 - val_loss: 0.0829 - val_mae: 0.0829 - lr: 0.0010
# Epoch 5/50
# 7/7 [==============================] - 1s 85ms/step - loss: 0.2504 - mae: 0.2504 - val_loss: 0.0788 - val_mae: 0.0788 - lr: 0.0010
# Epoch 6/50
# 7/7 [==============================] - 1s 92ms/step - loss: 0.3338 - mae: 0.3338 - val_loss: 0.0757 - val_mae: 0.0757 - lr: 0.0010
# Epoch 7/50
# 7/7 [==============================] - 1s 101ms/step - loss: 0.3214 - mae: 0.3214 - val_loss: 0.0733 - val_mae: 0.0733 - lr: 0.0010
# Epoch 8/50
# 7/7 [==============================] - 1s 92ms/step - loss: 0.2613 - mae: 0.2613 - val_loss: 0.0716 - val_mae: 0.0716 - lr: 0.0010
# Epoch 9/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2839 - mae: 0.2839 - val_loss: 0.0703 - val_mae: 0.0703 - lr: 0.0010
# Epoch 10/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.2772 - mae: 0.2772 - val_loss: 0.0695 - val_mae: 0.0695 - lr: 0.0010
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2035 - mae: 0.2035
# 7/7 [==============================] - 1s 117ms/step - loss: 0.2035 - mae: 0.2035 - val_loss: 0.0689 - val_mae: 0.0689 - lr: 0.0010
# Epoch 12/50
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2004 - mae: 0.2004 - val_loss: 0.0685 - val_mae: 0.0685 - lr: 0.0010
# Epoch 13/50
# 7/7 [==============================] - 1s 101ms/step - loss: 0.1964 - mae: 0.1964 - val_loss: 0.0682 - val_mae: 0.0682 - lr: 0.0010
# Epoch 14/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1946 - mae: 0.1946 - val_loss: 0.0681 - val_mae: 0.0681 - lr: 0.0010
# Epoch 15/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1940 - mae: 0.1940 - val_loss: 0.0680 - val_mae: 0.0680 - lr: 0.0010
# Epoch 16/50
# 7/7 [==============================] - 1s 102ms/step - loss: 0.1893 - mae: 0.1893 - val_loss: 0.0679 - val_mae: 0.0679 - lr: 0.0010
# Epoch 17/50
# 7/7 [==============================] - 1s 90ms/step - loss: 0.1865 - mae: 0.1865 - val_loss: 0.0678 - val_mae: 0.0678 - lr: 0.0010
# Epoch 18/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.1852 - mae: 0.1852 - val_loss: 0.0678 - val_mae: 0.0678 - lr: 0.0010
# Epoch 19/50
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1815 - mae: 0.1815 - val_loss: 0.0678 - val_mae: 0.0678 - lr: 0.0010
# Epoch 20/50
# 7/7 [==============================] - 1s 112ms/step - loss: 0.2191 - mae: 0.2191 - val_loss: 0.0677 - val_mae: 0.0677 - lr: 0.0010
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2533 - mae: 0.2533
# 7/7 [==============================] - 1s 92ms/step - loss: 0.2533 - mae: 0.2533 - val_loss: 0.0677 - val_mae: 0.0677 - lr: 0.0010
# Epoch 22/50
# 7/7 [==============================] - 1s 87ms/step - loss: 0.2119 - mae: 0.2119 - val_loss: 0.0677 - val_mae: 0.0677 - lr: 0.0010
# Epoch 23/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.2558 - mae: 0.2558 - val_loss: 0.0677 - val_mae: 0.0677 - lr: 0.0010
# Epoch 24/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.2115 - mae: 0.2115 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 0.0010
# Epoch 25/50
# 7/7 [==============================] - 1s 89ms/step - loss: 0.2071 - mae: 0.2071 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 0.0010
# Epoch 26/50
# 7/7 [==============================] - 1s 87ms/step - loss: 0.1747 - mae: 0.1747 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 0.0010
# Epoch 27/50
# 7/7 [==============================] - 1s 85ms/step - loss: 0.2353 - mae: 0.2353 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 0.0010
# Epoch 28/50
# 7/7 [==============================] - 1s 90ms/step - loss: 0.2410 - mae: 0.2410 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 0.0010
# Epoch 29/50
# 7/7 [==============================] - 1s 84ms/step - loss: 0.2326 - mae: 0.2326 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 0.0010
# Epoch 30/50
# 7/7 [==============================] - 1s 87ms/step - loss: 0.2299 - mae: 0.2299 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 0.0010
# Epoch 31/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2254 - mae: 0.2254
# 7/7 [==============================] - 1s 108ms/step - loss: 0.2254 - mae: 0.2254 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 32/50
# 7/7 [==============================] - 1s 110ms/step - loss: 0.2240 - mae: 0.2240 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 33/50
# 7/7 [==============================] - 1s 114ms/step - loss: 0.2259 - mae: 0.2259 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 34/50
# 7/7 [==============================] - 1s 100ms/step - loss: 0.2243 - mae: 0.2243 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 35/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2244 - mae: 0.2244 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 36/50
# 7/7 [==============================] - 1s 101ms/step - loss: 0.2159 - mae: 0.2159 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 37/50
# 7/7 [==============================] - 1s 100ms/step - loss: 0.2153 - mae: 0.2153 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 38/50
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2216 - mae: 0.2216 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 39/50
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2101 - mae: 0.2101 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 40/50
# 7/7 [==============================] - 1s 100ms/step - loss: 0.2099 - mae: 0.2099 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 41/50
# 7/7 [==============================] - ETA: 0s - loss: 0.2095 - mae: 0.2095
# 7/7 [==============================] - 1s 94ms/step - loss: 0.2095 - mae: 0.2095 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 42/50
# 7/7 [==============================] - 1s 92ms/step - loss: 0.2089 - mae: 0.2089 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-04
# Epoch 43/50
# 7/7 [==============================] - 1s 86ms/step - loss: 0.2080 - mae: 0.2080 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-05
# Epoch 44/50
# 7/7 [==============================] - 1s 93ms/step - loss: 0.2040 - mae: 0.2040 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-05
# Epoch 45/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.2059 - mae: 0.2059 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-05
# Epoch 46/50
# 7/7 [==============================] - 1s 93ms/step - loss: 0.2083 - mae: 0.2083 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-05
# Epoch 47/50
# 7/7 [==============================] - 1s 110ms/step - loss: 0.2031 - mae: 0.2031 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-05
# Epoch 48/50
# 7/7 [==============================] - 1s 90ms/step - loss: 0.2041 - mae: 0.2041 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-05
# Epoch 49/50
# 7/7 [==============================] - 1s 94ms/step - loss: 0.2105 - mae: 0.2105 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-05
# Epoch 50/50
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2034 - mae: 0.2034 - val_loss: 0.0676 - val_mae: 0.0676 - lr: 1.0000e-05
# 2/2 [==============================] - 0s 28ms/step
# WARNING:tensorflow:Layer lstm_169 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/50
#       9/Unknown - 2s 75ms/step - loss: 0.2168 - mae: 0.2168
# 9/9 [==============================] - 2s 116ms/step - loss: 0.2168 - mae: 0.2168 - val_loss: 0.0855 - val_mae: 0.0855 - lr: 0.0010
# Epoch 2/50
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1751 - mae: 0.1751 - val_loss: 0.0762 - val_mae: 0.0762 - lr: 0.0010
# Epoch 3/50
# 9/9 [==============================] - 1s 81ms/step - loss: 0.1667 - mae: 0.1667 - val_loss: 0.0704 - val_mae: 0.0704 - lr: 0.0010
# Epoch 4/50
# 9/9 [==============================] - 1s 87ms/step - loss: 0.1648 - mae: 0.1648 - val_loss: 0.0672 - val_mae: 0.0672 - lr: 0.0010
# Epoch 5/50
# 9/9 [==============================] - 1s 105ms/step - loss: 0.1665 - mae: 0.1665 - val_loss: 0.0658 - val_mae: 0.0658 - lr: 0.0010
# Epoch 6/50
# 9/9 [==============================] - 1s 97ms/step - loss: 0.1543 - mae: 0.1543 - val_loss: 0.0654 - val_mae: 0.0654 - lr: 0.0010
# Epoch 7/50
# 9/9 [==============================] - 1s 101ms/step - loss: 0.1443 - mae: 0.1443 - val_loss: 0.0655 - val_mae: 0.0655 - lr: 0.0010
# Epoch 8/50
# 9/9 [==============================] - 1s 91ms/step - loss: 0.2136 - mae: 0.2136 - val_loss: 0.0659 - val_mae: 0.0659 - lr: 0.0010
# Epoch 9/50
# 9/9 [==============================] - 1s 100ms/step - loss: 0.1529 - mae: 0.1529 - val_loss: 0.0664 - val_mae: 0.0664 - lr: 0.0010
# Epoch 10/50
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1550 - mae: 0.1550 - val_loss: 0.0667 - val_mae: 0.0667 - lr: 0.0010
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1490 - mae: 0.1490
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1490 - mae: 0.1490 - val_loss: 0.0669 - val_mae: 0.0669 - lr: 0.0010
# Epoch 12/50
# 9/9 [==============================] - 1s 83ms/step - loss: 0.1528 - mae: 0.1528 - val_loss: 0.0671 - val_mae: 0.0671 - lr: 0.0010
# Epoch 13/50
# 9/9 [==============================] - 1s 86ms/step - loss: 0.1500 - mae: 0.1500 - val_loss: 0.0671 - val_mae: 0.0671 - lr: 0.0010
# Epoch 14/50
# 9/9 [==============================] - 1s 82ms/step - loss: 0.1480 - mae: 0.1480 - val_loss: 0.0671 - val_mae: 0.0671 - lr: 0.0010
# Epoch 15/50
# 9/9 [==============================] - 1s 79ms/step - loss: 0.1465 - mae: 0.1465 - val_loss: 0.0671 - val_mae: 0.0671 - lr: 0.0010
# Epoch 16/50
# 9/9 [==============================] - 1s 89ms/step - loss: 0.1452 - mae: 0.1452 - val_loss: 0.0670 - val_mae: 0.0670 - lr: 0.0010
# Epoch 17/50
# 9/9 [==============================] - 1s 93ms/step - loss: 0.1438 - mae: 0.1438 - val_loss: 0.0670 - val_mae: 0.0670 - lr: 1.0000e-04
# Epoch 18/50
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1463 - mae: 0.1463 - val_loss: 0.0670 - val_mae: 0.0670 - lr: 1.0000e-04
# Epoch 19/50
# 9/9 [==============================] - 1s 78ms/step - loss: 0.1445 - mae: 0.1445 - val_loss: 0.0669 - val_mae: 0.0669 - lr: 1.0000e-04
# Epoch 20/50
# 9/9 [==============================] - 1s 85ms/step - loss: 0.1434 - mae: 0.1434 - val_loss: 0.0669 - val_mae: 0.0669 - lr: 1.0000e-04
# Epoch 21/50
# 9/9 [==============================] - ETA: 0s - loss: 0.1432 - mae: 0.1432
# 9/9 [==============================] - 1s 98ms/step - loss: 0.1432 - mae: 0.1432 - val_loss: 0.0669 - val_mae: 0.0669 - lr: 1.0000e-04
# Epoch 22/50
# 9/9 [==============================] - 1s 90ms/step - loss: 0.1427 - mae: 0.1427 - val_loss: 0.0669 - val_mae: 0.0669 - lr: 1.0000e-04
# Epoch 23/50
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1423 - mae: 0.1423 - val_loss: 0.0669 - val_mae: 0.0669 - lr: 1.0000e-04
# Epoch 24/50
# 9/9 [==============================] - 1s 81ms/step - loss: 0.1429 - mae: 0.1429 - val_loss: 0.0668 - val_mae: 0.0668 - lr: 1.0000e-04
# Epoch 25/50
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1403 - mae: 0.1403 - val_loss: 0.0668 - val_mae: 0.0668 - lr: 1.0000e-04
# Epoch 26/50
# 9/9 [==============================] - 1s 94ms/step - loss: 0.1392 - mae: 0.1392 - val_loss: 0.0668 - val_mae: 0.0668 - lr: 1.0000e-04
# 2/2 [==============================] - 1s 27ms/step

# %%
a = np.array(final_answer)
a = a.reshape(-1,1)
a.shape
# Out:
# (78336, 1)

# %%
a = np.array(answer)
a = a.reshape(-1,1)
a.shape
# Out:
# (23040, 1)

# %%
submit = pd.read_csv('./answer_sample.csv')
submit.iloc[:,-1] = a

# %%
submit.to_csv('./1_Densed_lstm_validation_epochs_80_interpolate_polynomial.csv')

# %% [markdown]
# ## 참고자료
# 시계열 데이터셋 구축
# * https://techblog-history-younghunjo1.tistory.com/373?category=922523
#
# 순환신경망 레이어 구축
# * https://www.linkedin.com/pulse/multivariate-multistep-lstm-rupak-roy
# * https://tykimos.github.io/2017/09/09/Time-series_Numerical_Input_Numerical_Prediction_Model_Recipe/
